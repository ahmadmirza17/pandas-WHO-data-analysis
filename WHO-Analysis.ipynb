# %%
import numpy as np
import pandas as pd
import os
import urllib
# %matplotlib inline

# %%
url = "https://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path = os.path.join("data", "covid")

# %%
os.makedirs(file_path, exist_ok=True)
csv_path = os.path.join(file_path, "WHO-COVID-19-global-data.csv")
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data/covid/WHO-COVID-19-global-data.csv',
#  <http.client.HTTPMessage at 0x7fce006960d0>)

# %%
df = pd.read_csv(csv_path)

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 126079    2021-06-13           ZW     Zimbabwe       AFRO        164
# 126080    2021-06-14           ZW     Zimbabwe       AFRO        107
# 126081    2021-06-15           ZW     Zimbabwe       AFRO        118
# 126082    2021-06-16           ZW     Zimbabwe       AFRO        241
# 126083    2021-06-17           ZW     Zimbabwe       AFRO        238
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df_index = df.index
df_index
# Out:
# RangeIndex(start=0, stop=126084, step=1)

# %%
df_cols = df.columns
df_cols
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df_index.values
# Out:
# array([     0,      1,      2, ..., 126081, 126082, 126083])

# %%
df.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2021-06-15', 'ZW', 'Zimbabwe', ..., 40077, 3, 1635],
#        ['2021-06-16', 'ZW', 'Zimbabwe', ..., 40318, 2, 1637],
#        ['2021-06-17', 'ZW', 'Zimbabwe', ..., 40556, 3, 1640]],
#       dtype=object)

# %%
df.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
df.shape
# Out:
# (126084, 8)

# %%
df.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
df.tail()
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 126079    2021-06-13           ZW  Zimbabwe       AFRO        164
# 126080    2021-06-14           ZW  Zimbabwe       AFRO        107
# 126081    2021-06-15           ZW  Zimbabwe       AFRO        118
# 126082    2021-06-16           ZW  Zimbabwe       AFRO        241
# 126083    2021-06-17           ZW  Zimbabwe       AFRO        238
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 126079             39852           3               1632
# 126080             39959           0               1632
# 126081             40077           3               1635
# 126082             40318           2               1637
# 126083             40556           3               1640

# %%
df.describe()
# Out:
#            New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  126084.000000      1.260840e+05  126084.000000      126084.000000
# mean     1401.398972      2.329202e+05      30.378985        5666.228530
# std      9604.507690      1.471405e+06     170.986630       29859.200851
# min    -32952.000000      0.000000e+00     -60.000000           0.000000
# 25%         0.000000      1.900000e+01       0.000000           0.000000
# 50%         7.000000      2.385000e+03       0.000000          40.000000
# 75%       292.000000      4.606425e+04       4.000000         764.000000
# max    414188.000000      3.316363e+07    6508.000000      595256.000000

# %%
df.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
df.Country == 'Singapore'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126079    False
# 126080    False
# 126081    False
# 126082    False
# 126083    False
# Name: Country, Length: 126084, dtype: bool

# %%
df[df.Country == 'Singapore']
# Out:
#        Date_reported Country_code    Country WHO_region  New_cases  \
# 102676    2020-01-03           SG  Singapore       WPRO          0
# 102677    2020-01-04           SG  Singapore       WPRO          0
# 102678    2020-01-05           SG  Singapore       WPRO          0
# 102679    2020-01-06           SG  Singapore       WPRO          0
# 102680    2020-01-07           SG  Singapore       WPRO          0
# ...              ...          ...        ...        ...        ...
# 103203    2021-06-13           SG  Singapore       WPRO         18
# 103204    2021-06-14           SG  Singapore       WPRO         13
# 103205    2021-06-15           SG  Singapore       WPRO         25
# 103206    2021-06-16           SG  Singapore       WPRO         14
# 103207    2021-06-17           SG  Singapore       WPRO         24
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 102676                 0           0                  0
# ...

# %%
df[df.New_deaths >= 1000]
# Out:
#        Date_reported Country_code                           Country  \
# 4530      2020-10-03           AR                         Argentina
# 13017     2020-09-08           BO  Bolivia (Plurinational State of)
# 15035     2020-05-21           BR                            Brazil
# 15037     2020-05-23           BR                            Brazil
# 15038     2020-05-24           BR                            Brazil
# ...              ...          ...                               ...
# 120675    2021-03-21           US          United States of America
# 120680    2021-03-26           US          United States of America
# 120681    2021-03-27           US          United States of America
# 120682    2021-03-28           US          United States of America
# 120743    2021-05-28           US          United States of America
#
#        WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df.loc[df.New_deaths >= 1000, ['New_deaths','Country']]
# Out:
#         New_deaths                           Country
# 4530          3351                         Argentina
# 13017         1610  Bolivia (Plurinational State of)
# 15035         1179                            Brazil
# 15037         1188                            Brazil
# 15038         1001                            Brazil
# ...            ...                               ...
# 120675        1359          United States of America
# 120680        1091          United States of America
# 120681        1237          United States of America
# 120682        1170          United States of America
# 120743        1120          United States of America
#
# [623 rows x 2 columns]

# %%
df.loc[(df.New_deaths >= 1000) & (df.Country_code == 'US'),['Date_reported','Country','New_cases','New_deaths','Cumulative_deaths']]
# Out:
#        Date_reported                   Country  New_cases  New_deaths  \
# 120325    2020-04-05  United States of America      35131        1067
# 120326    2020-04-06  United States of America      30593        1157
# 120327    2020-04-07  United States of America      25511        1364
# 120328    2020-04-08  United States of America      42604        3243
# 120330    2020-04-10  United States of America      31714        1958
# ...              ...                       ...        ...         ...
# 120675    2021-03-21  United States of America      61405        1359
# 120680    2021-03-26  United States of America      65751        1091
# 120681    2021-03-27  United States of America      67796        1237
# 120682    2021-03-28  United States of America      71388        1170
# 120743    2021-05-28  United States of America      24462        1120
#
#         Cumulative_deaths
# 120325               6856
# 120326               8013
# 120327               9377
# ...

# %%
df.loc[df.Country_code == 'SG',['New_cases']].max()
# Out:
# New_cases    1426
# dtype: int64

# %%
df.loc[df.Country_code == 'SG',['New_cases']].min()
# Out:
# New_cases    0
# dtype: int64

# %%
df.loc[df.Country_code == 'SG',['New_cases']].sum()
# Out:
# New_cases    62339
# dtype: int64

# %%
df.loc[df.Country_code == 'SG',['Cumulative_cases']].max()
# Out:
# Cumulative_cases    62339
# dtype: int64

# %%
df.New_cases[df.Country_code == 'SG'].idxmax()
# Out:
# 102785

# %%
df.loc[df.New_cases[df.Country_code == 'SG'].idxmax(),['Date_reported','Country','New_cases','New_deaths','Cumulative_deaths']]
# Out:
# Date_reported        2020-04-21
# Country               Singapore
# New_cases                  1426
# New_deaths                    0
# Cumulative_deaths            11
# Name: 102785, dtype: object

# %%
df[df.New_deaths < 0]
# Out:
#        Date_reported Country_code                Country WHO_region  \
# 1278      2020-08-04           DZ                Algeria       AFRO
# 2936      2020-10-05           AO                 Angola       AFRO
# 7688      2020-08-30           BS                Bahamas       AMRO
# 7905      2021-04-04           BS                Bahamas       AMRO
# 17216     2020-07-13           BF           Burkina Faso       AFRO
# 24098     2020-06-09           CG                  Congo       AFRO
# 26825     2020-08-15           CU                   Cuba       AMRO
# 28380     2020-07-05           CZ                Czechia       EURO
# 28381     2020-07-06           CZ                Czechia       EURO
# 34410     2020-12-30           ER                Eritrea       AFRO
# 34495     2021-03-25           ER                Eritrea       AFRO
# 35352     2020-08-30           SZ               Eswatini       AFRO
# 35559     2021-03-25           SZ               Eswatini       AFRO
# ...

# %%
# Percentage of which new cases are to the total cases
df['pct_cases'] = (df['New_cases']/df['Cumulative_cases']) * 100
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 126079    2021-06-13           ZW     Zimbabwe       AFRO        164
# 126080    2021-06-14           ZW     Zimbabwe       AFRO        107
# 126081    2021-06-15           ZW     Zimbabwe       AFRO        118
# 126082    2021-06-16           ZW     Zimbabwe       AFRO        241
# 126083    2021-06-17           ZW     Zimbabwe       AFRO        238
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  pct_cases
# 0                      0           0                  0        NaN
# ...

# %%
import matplotlib.dates as mdates
ax = df[df.Country == 'Singapore'].plot.bar(x='Date_reported', y='New_cases', figsize=(25,14))

#set ticks every week
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#format date
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

ax.set_title('New daily reported cases in Singapore')
ax.set_ylabel('Number of cases')
ax.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')
